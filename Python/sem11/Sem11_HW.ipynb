# %%
import pandas as pd

# %%
df = pd.read_csv('train (2).csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# def is_lucky_ticket(arg):

#     if ' ' in str(arg):
#         temp = arg.split()[-1]
#     else:
#         temp = arg
#     middle = len(str(temp))//2
#     print(temp)
#     return sum([int(i) for i in str(temp)[:middle]]) == sum([int(i) for i in str(temp)[-middle:]])
# Тут я пытался сопоставить зависимость выживших от наличия "счастливого билета", но постоянно натыкался на ошибку

# %%
df.groupby([ 'Embarked', 'Survived']).agg({'Survived': 'sum'})
# Тут можно увидеть, что максимальное количество выживиших из Саутгемптона
# Out:
#                    Survived
# Embarked Survived
# C        0                0
#          1               93
# Q        0                0
#          1               30
# S        0                0
#          1              217

# %%
df.Embarked.value_counts()
# Хотя это не удивительно, ведь там села большая часть пассажиров
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.groupby([ 'Sex', 'Survived']).agg({'Survived': 'sum'})

# Тут видим, что женщин спаслось примерно в два раза больше
# Out:
#                  Survived
# Sex    Survived
# female 0                0
#        1              233
# male   0                0
#        1              109

# %%
df.Age.value_counts()
# Тут видим, что больше всего было 24-летних
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
df.groupby([ 'Pclass', 'Survived']).agg({'Survived': 'sum'})

# а тут количество выживших по классам
# Out:
#                  Survived
# Pclass Survived
# 1      0                0
#        1              136
# 2      0                0
#        1               87
# 3      0                0
#        1              119
